# %% [markdown]
# <a href="https://colab.research.google.com/github/piusAI/Pytorch-Tutorial-Codemy.com/blob/main/05_Simple_NeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Iris Data Set
# https://archive.ics.uci.edu/dataset/53/iris
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
# - Class : 3 (Red BOX)
# - Features :4 (Green BOX)

# %% [markdown]
# # Neural Network
#
# ![image.png](data:image/png;base64,...)
#
# => Input Layer, Hidden Layer, OutputLayer

# %% [markdown]
# In Classification Method
# ---
#
# *   Forward Propagation is used to Compute **Class Propabilities**
# *   Forward Propagation is used to Compute **Predictions**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# Create a Model Class that inherits nn.Module         => OOP Programing! based on Class!
class Model(nn.Module):
  # Input Layer( 4 features of the Flower) ==>
  # Hidden Layer1 ( number of Neurons ) ==>
  # H2 (n) ==>
  # Output(3 classes of iris flowers)
  def __init__(self, in_features=4, h1=8, h2=9, out_features=3):
    super().__init__() #Instantiate our nn.Module
    self.fc1= nn.Linear(in_features,h1)           # Affine   ## fc : fully-connected layer
    self.fc2=nn.Linear(h1,h2)                     # Affine
    self.out=nn.Linear(h2,out_features)           # Affine
  def forward(self, x):
    x = F.relu(self.fc1(x))                       ## Relu
    x = F.relu(self.fc2(x))
    x = self.out(x)
    return x

# %% [markdown]
# ###Affine 세번연속 실행!?
# Affine => Sigmoid => Affine => Sigmoid => SoftMax를 표현해야 Classfication에서의 Predict이지만,
#
# - nn.Linear는 Linear변환인 y=Wx+b만을 한다(SLP)
#
# MLP를 구현하기 위해서는 Simoid를 활용해야하기에
# - x=F.sigmoid(self.fc1(x)) #fc1의 linear output에 추후 sigmoid를 적용 할 것 으로 추정.

# %% [markdown]
# ##Activation Function
#
# ![image.png](data:image/png;base64,...)
#
# Sigmoid가 아닌 Relu로 처리

# %% [markdown]
# super().__init__()
#
# =>nn.Module 상속시,
#
# nn.Module의 초기화를 한번 꼭 해야지된다!
#
# 하지 않는다면?
# - 내부적으로 model.parameters(), model.to(device)와 같은 기능 작동 X
# - Forward 연결, GPU, 학습 등 Error 발생!

# %%
#Pick a Manual Seed For Randomization
torch.manual_seed(41)

#Create An Instance Of Model
model = Model()

# %% [markdown]
# Next... Con Ti Nue...
# import Data set!
